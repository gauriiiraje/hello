# %% [markdown]
# ## Decision tree for Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds = pd.read_excel(r"C:\Users\student\Downloads\SMLP Practicals\Excel data\linear_regression_data.xlsx")

# %%
ds.head()
# Out:
#    X1_Experience  X2_TestScore  Y_Salary
# 0             52           109    288.61
# 1             93            90    365.27
# 2             15            78    170.82
# 3             72            64    276.85
# 4             61            94    303.87

# %%
sns.pairplot(data=ds)

# %%
x= ds.iloc[:,:-1]
y= ds["Y_Salary"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=82)

# %%
from sklearn.tree import DecisionTreeRegressor,plot_tree

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtr.score(x_test,y_test)*100, dtr.score(x_train,y_train)*100
# Out:
# (85.60781885406344, 100.0)

# %%
plt.figure(figsize=(50,50))
plot_tree(dtr)
plt.show()
