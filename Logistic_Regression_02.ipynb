# %% [markdown]
# ## Logistic Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
import seaborn as sns

# %%
ds = pd.read_excel(r"C:\Users\student\Downloads\SMLP Practicals\Excel data\placement_logistic_data.xlsx")

# %%
ds.head()
# Out:
#    CGPA  Score  Placed
# 0  6.87  78.87       0
# 1  9.75  67.53       1
# 2  8.66  51.67       1
# 3  7.99  86.97       0
# 4  5.78  77.93       0

# %%
sns.scatterplot(x="CGPA",y="Score",data=ds,hue="Placed")
plt.legend(loc=1)

# %%
x=ds.iloc[:,:-1]
y = ds["Placed"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=82)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 76.0

# %%
lr.score(x_train,y_train)*100
# Out:
# 75.0

# %%
lr.predict([[6.87,78.87]])
# Out:
# C:\Users\student\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
lr.predict([[6.87,78.87]])
# Out:
# C:\Users\student\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
lr.predict([[9.75,67.53]])
# Out:
# C:\Users\student\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
pip install mlxtend
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 57.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lr)
plt.savefig("decision.jpg")
plt.show()
# Out:
# C:\Users\student\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
