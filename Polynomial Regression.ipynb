# %% [markdown]
# ## Polynomial Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
ds = pd.read_excel(r"C:\Users\student\Downloads\SMLP Practicals\polynomial_regression_data.xlsx")

# %%
ds.head()
# Out:
#    X   Y
# 0  1  11
# 1  2  61
# 2  3  -4
# 3  4  70
# 4  5  80

# %%
ds.corr()
# Out:
#           X         Y
# X  1.000000  0.969506
# Y  0.969506  1.000000

# %%
plt.scatter(ds["X"],ds["Y"])

# %%
x= ds[["X"]]
y= ds["Y"]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree=2)
pf.fit(x)
pf.transform(x)
# Out:
# array([[1.000e+00, 1.000e+00, 1.000e+00],
#        [1.000e+00, 2.000e+00, 4.000e+00],
#        [1.000e+00, 3.000e+00, 9.000e+00],
#        [1.000e+00, 4.000e+00, 1.600e+01],
#        [1.000e+00, 5.000e+00, 2.500e+01],
#        [1.000e+00, 6.000e+00, 3.600e+01],
#        [1.000e+00, 7.000e+00, 4.900e+01],
#        [1.000e+00, 8.000e+00, 6.400e+01],
#        [1.000e+00, 9.000e+00, 8.100e+01],
#        [1.000e+00, 1.000e+01, 1.000e+02],
#        [1.000e+00, 1.100e+01, 1.210e+02],
#        [1.000e+00, 1.200e+01, 1.440e+02],
#        [1.000e+00, 1.300e+01, 1.690e+02],
#        [1.000e+00, 1.400e+01, 1.960e+02],
#        [1.000e+00, 1.500e+01, 2.250e+02],
#        [1.000e+00, 1.600e+01, 2.560e+02],
#        [1.000e+00, 1.700e+01, 2.890e+02],
#        [1.000e+00, 1.800e+01, 3.240e+02],
#        [1.000e+00, 1.900e+01, 3.610e+02],
#        [1.000e+00, 2.000e+01, 4.000e+02],
#        [1.000e+00, 2.100e+01, 4.410e+02],
#        [1.000e+00, 2.200e+01, 4.840e+02],
# ...

# %%
x=pf.transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=82)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 99.99577362376327

# %%
pred= lr.predict(x)

# %%
plt.scatter(ds["X"],ds["Y"])
plt.plot(ds["X"],pred,c="red")
plt.legend(["org_data","predict_line"])

# %%
test = pf.transform([[40]])
# Out:
# C:\Users\student\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([[1.0e+00, 4.0e+01, 1.6e+03]])

# %%
lr.predict(test)
# Out:
# array([3321.69623865])
